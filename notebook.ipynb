# %%
import pandas as pd
import numpy as np

# %%
chi_weather = pd.read_csv('chicago_weather.csv')

# %%
chi_weath = chi_weather[39182:]
chi_weath
# Out:
#            STATION        DATE   AWND  DAPR  MDPR  PGTM  PRCP  SNOW  SNWD  \
# 39182  USW00094846  2019-01-01   7.61   NaN   NaN   NaN  0.01   0.1   0.0
# 39183  USW00094846  2019-01-02   8.72   NaN   NaN   NaN  0.01   0.1   0.0
# 39184  USW00094846  2019-01-03  11.63   NaN   NaN   NaN  0.00   0.0   0.0
# 39185  USW00094846  2019-01-04   8.05   NaN   NaN   NaN  0.00   0.0   0.0
# 39186  USW00094846  2019-01-05   8.28   NaN   NaN   NaN  0.00   0.0   0.0
# ...            ...         ...    ...   ...   ...   ...   ...   ...   ...
# 39542  USW00094846  2019-12-27   7.16   NaN   NaN   NaN  0.00   0.0   0.0
# 39543  USW00094846  2019-12-28   6.93   NaN   NaN   NaN  0.28   0.0   0.0
# 39544  USW00094846  2019-12-29  10.96   NaN   NaN   NaN  0.93   0.0   0.0
# 39545  USW00094846  2019-12-30  17.67   NaN   NaN   NaN  0.09   0.7   0.0
# 39546  USW00094846  2019-12-31  14.54   NaN   NaN   NaN  0.08   0.8   2.0
#
#        TAVG  ...  WSF5  WT01  WT02  WT03  WT04  WT05  WT06  WT08  WT09  WT11
# ...
